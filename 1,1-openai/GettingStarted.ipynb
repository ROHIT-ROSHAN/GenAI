# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")
#Langsmith tracking
os.environ['LANGCHAIN_API_KEY'] = os.getenv("LANGCHAIN_API_KEY")
os.environ['LANGCHAIN_TRACING_V2'] = "true"
os.environ['LANGCHAIN_PROJECT'] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4.1-2025-04-14")
print(llm)
# Out:
# c:\Coding\AI\GEN AI\venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# profile={} client=<openai.resources.chat.completions.completions.Completions object at 0x000001A5856D3CB0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001A585878830> root_client=<openai.OpenAI object at 0x000001A58514D6A0> root_async_client=<openai.AsyncOpenAI object at 0x000001A585878590> model_name='gpt-4.1-2025-04-14' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
#Input and Get Response from LLM
result =llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI is a type of artificial intelligence that **creates new content**—such as text, images, audio, video, or code—based on patterns it learned from large amounts of training data.\n\n### How it works (high level)\n- A generative model learns statistical patterns in existing data (e.g., how sentences are structured or what images of “cats” typically look like).\n- When you give it a prompt, it **predicts and produces** a new output that fits those patterns.\n\n### Common examples\n- **Text:** Chatbots and writing assistants that draft emails, summarize documents, or answer questions.\n- **Images:** Tools that generate illustrations or realistic photos from prompts.\n- **Code:** Systems that autocomplete code or generate functions from descriptions.\n- **Audio/Video:** Voice synthesis, music generation, or video creation/editing.\n\n### Key point\nGenerative AI doesn’t “retrieve” a perfect copy of something it has seen; it **generates** a new result that is similar in style or structure—though it can sometimes reproduce or closely resemble training examples.\n\nIf you tell me what kind of content you’re interested in (text, images, code, etc.), I can give a more specific explanation and examples.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 254, 'prompt_tokens': 12, 'total_tokens': 266, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.2-2025-12-11', 'system_fingerprint': None, 'id': 'chatcmpl-DDZgQLTc6tC6xEz9VeUgO2qEuMwj1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c9b0c-4c76-7b71-b140-d68fd6f1e26a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 254, 'total_tokens': 266, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
## ChatPrompt Template
from langchain_core.prompts import ChatPromptTemplate
# Tells the llm model to behave in a certain way
prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the question"),
        ("user", "{input}"),

    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
# Chain 
chain = prompt|llm
response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='LangSmith is a platform from LangChain for **developing, debugging, evaluating, and monitoring** applications built with LLMs (and more generally, “AI agents” / tool-using workflows). It’s especially useful when your system involves multiple steps—prompts, retrieval, tool calls, structured outputs—where you need visibility and measurement rather than guesswork.\n\n## What LangSmith is for\n1. **Tracing & Debugging (Observability)**\n   - Captures detailed traces of each run: prompt inputs/outputs, tool calls, retrieval results, intermediate steps, latencies, and errors.\n   - Lets you drill into a single user request and see exactly where the behavior went wrong (e.g., bad retrieved docs, malformed tool output, prompt regression).\n\n2. **Evaluation (Evals)**\n   - Run repeatable tests against datasets of examples (questions, expected outputs, grading criteria).\n   - Supports automated evaluators (LLM-as-judge, heuristics, regex/JSON validation, similarity metrics) and human review/labeling.\n   - Compare versions of prompts/models/agents to detect regressions.\n\n3. **Datasets & Experiment Tracking**\n   - Store curated datasets (inputs + expected outputs or reference answers).\n   - Track experiments across different prompt/model configurations and compare results over time.\n\n4. **Production Monitoring**\n   - Track real-world performance: success rates, latency, token usage/cost, error types.\n   - Identify problematic inputs, drift, and edge cases to feed back into your eval sets.\n\n## How it fits into an LLM app stack\n- **During development:** you instrument your chain/agent so every run is traced.\n- **During testing:** you run evals over a dataset to choose the best prompt/model/tooling.\n- **In production:** you keep tracing enabled (often sampled) to monitor reliability and cost.\n\n## Typical use cases\n- RAG apps: verify the retriever is pulling relevant sources and that the model is grounding answers.\n- Agentic workflows: see each tool call and whether the tool outputs are being interpreted correctly.\n- Prompt iteration: compare prompt versions with objective eval scores.\n- Guardrails/structured output: validate JSON schemas and detect formatting failures.\n\n## Key concepts (high level)\n- **Run / Trace:** a single execution and its step-by-step breakdown.\n- **Project:** a namespace for traces/experiments (e.g., “prod-chatbot” vs “prompt-tests”).\n- **Dataset:** stored test cases for evaluation.\n- **Evaluator:** a scoring function (LLM-based or deterministic).\n- **Feedback:** human or automated labels attached to runs (useful for continuous improvement).\n\n## What you need to use it\n- Instrumentation via LangChain is common, but you can also integrate tracing patterns into non-LangChain code depending on your stack.\n- You typically set an API key and enable tracing; then runs show up in the LangSmith UI.\n\n## When it’s most valuable\n- When your app has **multiple steps** (RAG + tools + routing).\n- When you need **repeatable quality checks** (evals) and **regression detection**.\n- When debugging from logs alone is too slow.\n\nIf you tell me your setup (LangChain vs custom Python/TS, RAG vs agent, and whether it’s dev or production), I can outline the most relevant way to integrate LangSmith and what metrics/evals to start with.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 705, 'prompt_tokens': 32, 'total_tokens': 737, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.2-2025-12-11', 'system_fingerprint': None, 'id': 'chatcmpl-DDZgaoCYWupqZV5T6NcGePK7u9tZ8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c9b0c-73e1-7ad0-aa43-e35a40fa6bc2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_token ...

# %%
#stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt|llm|output_parser
response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Certainly! **LangSmith** is a platform developed by [LangChain](https://www.langchain.com/), designed to assist with the development, evaluation, debugging, and monitoring of applications that use Large Language Models (LLMs). Here’s an overview:
#
# ---
#
# ### What is LangSmith?
#
# - **LangSmith** is an end-to-end developer platform and observability suite tailored for LLM-driven applications.
# - It supports the entire lifecycle of LLM application development: prototyping, testing, evaluation, deployment, and monitoring.
# - **It is particularly designed** for teams building with LangChain, but can also be integrated with other LLM frameworks via API.
#
# ---
#
# ### Key Features
#
# 1. **Tracing and Debugging**
#    - Provides detailed tracing of LLM interactions, prompts, chains, tools, and agents.
#    - Helps debug and understand how data flows through your LLM application.
#
# 2. **Dataset Management**
#    - Allows you to create, store, and curate datasets (questions, tasks, etc.) to benchmark and evaluate your application.
#    - Supports uploading and versioning datasets.
#
# 3. **Evaluation & Metrics**
#    - Built-in evaluation of model outputs using both automated (e.g., accuracy, F1) and LLM-assisted methods.
#    - Visual dashboards to compare prompts, agents, and model versions.
#
# 4. **Monitoring & Logging**
#    - Monitors applications in production—logs inputs, outputs, errors, latency, token usage, and costs.
#    - Enables alerts and audits for reliability and compliance.
#
# 5. **Collaboration**
#    - Teams can share, reproduce, and analyze traces, tests, and datasets.
#
# 6. **Integrations**
#    - Native support for LangChain applications.
#    - API and SDKs for integration with various LLM applications or frameworks (e.g., Python, JavaScript).
#
# ---
#
# ### How is LangSmith Used?
#
# - **Developers**: For rapid prototyping and debugging of complex LLM pipelines.
# - **QA & Evaluation**: For automated, scalable evaluation and regression testing.
# - **Product**: For monitoring and improving user-facing LLM features.
#
# ---
#
# ### Why Use LangSmith?
#
# - **Reduces development friction:** Quickly find and fix issues in complex LLM workflows.
# - **Ensures quality:** Systematic evaluation helps maintain and improve output quality as prompts, chains, or LLMs change.
# - **Improves transparency:** Detailed observability and audit trails across the entire LLM stack.
#
# ---
#
# ### Example Use Case
#
# Suppose you’re developing a retrieval augmented generation (RAG) chatbot with LangChain:
# - LangSmith lets you trace each request, inspect model outputs at each stage, test against datasets of user questions, evaluate with human/LLM metrics, and monitor production interactions—all in one platform.
#
# ---
#
# ### Getting Started
#
# - Visit the [LangSmith documentation](https://docs.smith.langchain.com/) for setup guides and SDK usage.
# - Sign up for an account on [smith.langchain.com](https://smith.langchain.com/).
#
# ---
#
# **In summary:**
# LangSmith is like “datadog + Sentry + evals” for LLM applications, helping teams accelerate and safeguard the development of reliable, high-quality generative AI solutions.
